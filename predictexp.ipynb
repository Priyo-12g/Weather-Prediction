# %% [markdown]
# # Importing Libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt

weather = pd.read_csv("weather.csv", index_col="DATE") #taking date as the index column

# %% [markdown]
# # Reading DATA

# %%
weather #print the whole dataset
# Out:
#                 STATION                              NAME  ACMH   ACSH   AWND  \
# DATE
# 1970-01-01  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  80.0   90.0    NaN
# 1970-01-02  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  30.0   20.0    NaN
# 1970-01-03  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  80.0  100.0    NaN
# 1970-01-04  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  10.0   20.0    NaN
# 1970-01-05  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  30.0   10.0    NaN
# ...                 ...                               ...   ...    ...    ...
# 2022-10-17  USW00094789  JFK INTERNATIONAL AIRPORT, NY US   NaN    NaN   9.62
# 2022-10-18  USW00094789  JFK INTERNATIONAL AIRPORT, NY US   NaN    NaN  12.08
# 2022-10-19  USW00094789  JFK INTERNATIONAL AIRPORT, NY US   NaN    NaN  14.99
# 2022-10-20  USW00094789  JFK INTERNATIONAL AIRPORT, NY US   NaN    NaN  16.78
# 2022-10-21  USW00094789  JFK INTERNATIONAL AIRPORT, NY US   NaN    NaN    NaN
#
# ...

# %% [markdown]
# # Handle Missing Values

# %%
null_pct = weather.apply(pd.isnull).sum()/weather.shape[0] #shows the percentage of null value
null_pct #print the null values
# Out:
# STATION    0.000000
# NAME       0.000000
# ACMH       0.501478
# ACSH       0.501426
# AWND       0.265256
# FMTM       0.475087
# PGTM       0.363872
# PRCP       0.000000
# SNOW       0.000000
# SNWD       0.000104
# TAVG       0.680406
# TMAX       0.000000
# TMIN       0.000000
# TSUN       0.998393
# WDF1       0.501685
# WDF2       0.498678
# WDF5       0.502981
# WDFG       0.734484
# WDFM       0.999948
# WESD       0.685228
# WSF1       0.501530
# WSF2       0.498678
# WSF5       0.503033
# WSFG       0.613055
# WSFM       0.999948
# WT01       0.630217
# WT02       0.935034
# WT03       0.933271
# WT04       0.982579
# WT05       0.981127
# WT06       0.990615
# WT07       0.994400
# WT08       0.796962
# WT09       0.992741
# WT11       0.999274
# WT13       0.886711
# WT14       0.954010
# WT15       0.997822
# WT16       0.658993
# WT17       0.996889
# WT18       0.939493
# WT21       0.999741
# WT22       0.997459
# WV01       0.999948
# dtype: float64

# %%
valid_columns = weather.columns[null_pct < .05] # would contain the column names of weather where the percentage of null values is less than 5%. 
#These are the columns with relatively few missing values.

# %%
valid_columns
# Out:
# Index(['STATION', 'NAME', 'PRCP', 'SNOW', 'SNWD', 'TMAX', 'TMIN'], dtype='object')

# %%
weather = weather[valid_columns].copy() # the DataFrame weather will contain only the columns with a percentage of null values less than 5%.

# %%
weather.columns = weather.columns.str.lower() # all columns names will be in lower case

# %%
weather
# Out:
#                 station                              name  prcp  snow  snwd  \
# DATE
# 1970-01-01  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1970-01-02  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1970-01-03  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.02   0.0   0.0
# 1970-01-04  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1970-01-05  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# ...                 ...                               ...   ...   ...   ...
# 2022-10-17  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.08   0.0   0.0
# 2022-10-18  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2022-10-19  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2022-10-20  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2022-10-21  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
#
#             tmax  tmin
# DATE
# ...

# %%
weather = weather.ffill() #it will get replaced with any recent null values which are missing

# %%
weather.apply(pd.isnull).sum() # each element represents the count of missing values for the corresponding column
# Out:
# station    0
# name       0
# prcp       0
# snow       0
# snwd       0
# tmax       0
# tmin       0
# dtype: int64

# %% [markdown]
# # Data Preprocessing

# %%
weather.apply(lambda x: (x == 9999).sum())
# Out:
# station    0
# name       0
# prcp       0
# snow       0
# snwd       0
# tmax       0
# tmin       0
# dtype: int64

# %%
weather.dtypes
# Out:
# station     object
# name        object
# prcp       float64
# snow       float64
# snwd       float64
# tmax         int64
# tmin         int64
# dtype: object

# %%
weather.index
# Out:
# Index(['1970-01-01', '1970-01-02', '1970-01-03', '1970-01-04', '1970-01-05',
#        '1970-01-06', '1970-01-07', '1970-01-08', '1970-01-09', '1970-01-10',
#        ...
#        '2022-10-12', '2022-10-13', '2022-10-14', '2022-10-15', '2022-10-16',
#        '2022-10-17', '2022-10-18', '2022-10-19', '2022-10-20', '2022-10-21'],
#       dtype='object', name='DATE', length=19287)

# %%
weather.index = pd.to_datetime(weather.index)

# %%
weather.index.year.value_counts().sort_index()
# Out:
# DATE
# 1970    365
# 1971    365
# 1972    366
# 1973    365
# 1974    365
# 1975    365
# 1976    366
# 1977    365
# 1978    365
# 1979    365
# 1980    366
# 1981    365
# 1982    365
# 1983    365
# 1984    366
# 1985    365
# 1986    365
# 1987    365
# 1988    366
# 1989    365
# 1990    365
# 1991    365
# 1992    366
# 1993    365
# 1994    365
# 1995    365
# 1996    366
# 1997    365
# 1998    365
# 1999    365
# 2000    366
# 2001    365
# 2002    365
# 2003    365
# 2004    366
# 2005    365
# 2006    365
# 2007    365
# 2008    366
# 2009    365
# 2010    365
# 2011    365
# 2012    366
# 2013    365
# 2014    365
# 2015    365
# 2016    366
# 2017    365
# 2018    365
# 2019    365
# 2020    366
# 2021    365
# 2022    294
# Name: count, dtype: int64

# %%
weather["snwd"].plot() #create a bar plot of how much snow accumulated
# Out:
# <Axes: xlabel='DATE'>

# %%
weather["prcp"].plot()
# Out:
# <Axes: xlabel='DATE'>

# %% [markdown]
# # Model Training

# %%
weather["target"] = weather.shift(-1)["tmax"] #we will be predicting tommorow max temp

# %%
weather
# Out:
#                 station                              name  prcp  snow  snwd  \
# DATE
# 1970-01-01  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1970-01-02  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1970-01-03  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.02   0.0   0.0
# 1970-01-04  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1970-01-05  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# ...                 ...                               ...   ...   ...   ...
# 2022-10-17  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.08   0.0   0.0
# 2022-10-18  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2022-10-19  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2022-10-20  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2022-10-21  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
#
#             tmax  tmin  target
# DATE
# ...

# %%
weather = weather.ffill() #to fill the missing values

# %%
weather
# Out:
#                 station                              name  prcp  snow  snwd  \
# DATE
# 1970-01-01  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1970-01-02  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1970-01-03  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.02   0.0   0.0
# 1970-01-04  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1970-01-05  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# ...                 ...                               ...   ...   ...   ...
# 2022-10-17  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.08   0.0   0.0
# 2022-10-18  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2022-10-19  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2022-10-20  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2022-10-21  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
#
#             tmax  tmin  target
# DATE
# ...

# %% [markdown]
# # Model Training and Testing

# %%
from sklearn.linear_model import Ridge #ridge regression model

rr = Ridge(alpha=.1) #alpha parameter controls how much the coefficients are shrunk to account for collinearity

# %%
predictors = weather.columns[~weather.columns.isin(["target", "name", "station"])] #gives al the columns except this columns

# %%
predictors
# Out:
# Index(['prcp', 'snow', 'snwd', 'tmax', 'tmin'], dtype='object')

# %%
def backtest(weather, model, predictors, start=3650, step=90):
    all_predictions = [] #the predictions willbe added to this list
    #This loop iterates over the rows of the weather DataFrame in steps of step
    for i in range(start, weather.shape[0], step):
        train = weather.iloc[:i,:]
        test = weather.iloc[i:(i+step),:]
        
        model.fit(train[predictors], train["target"])
        
        preds = model.predict(test[predictors])
        preds = pd.Series(preds, index=test.index)
        combined = pd.concat([test["target"], preds], axis=1)
        combined.columns = ["actual", "prediction"]
        combined["diff"] = (combined["prediction"] - combined["actual"]).abs()
         #this loop will generate prediction for 90 days
        all_predictions.append(combined)
    return pd.concat(all_predictions) #return this prediction into very very long dataframe

# %%
predictions = backtest(weather, rr, predictors)

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error

mean_absolute_error(predictions["actual"], predictions["prediction"])
# Out:
# 5.13932667966084

# %%
predictions.sort_values("diff", ascending=False)
# Out:
#             actual  prediction       diff
# DATE
# 2007-03-26    78.0   49.744725  28.255275
# 1999-01-02    53.0   25.911898  27.088102
# 1998-03-26    80.0   53.033957  26.966043
# 1985-04-18    84.0   57.071179  26.928821
# 1990-03-12    85.0   58.144310  26.855690
# ...            ...         ...        ...
# 2006-08-20    88.0   88.002937   0.002937
# 2019-03-01    40.0   40.002460   0.002460
# 1992-06-11    76.0   76.001641   0.001641
# 2011-09-16    66.0   66.000831   0.000831
# 2014-03-25    39.0   38.999920   0.000080
#
# [15637 rows x 3 columns]

# %%
pd.Series(rr.coef_, index=predictors)
# Out:
# prcp   -1.236110
# snow   -0.407827
# snwd    0.053422
# tmax    0.447413
# tmin    0.517302
# dtype: float64

# %% [markdown]
# # Model Evaluation and Feature Engineering

# %%
def pct_diff(old, new):
    return (new - old) / old

def compute_rolling(weather, horizon, col):
    label = f"rolling_{horizon}_{col}"
    weather[label] = weather[col].rolling(horizon).mean() #it will find the avg tmax
    weather[f"{label}_pct"] = pct_diff(weather[label], weather[col])
    return weather
    
rolling_horizons = [3, 14] #runs for 3 and 14 days
for horizon in rolling_horizons:
    for col in ["tmax", "tmin", "prcp"]:
        weather = compute_rolling(weather, horizon, col)

# %%
def expand_mean(df):
    return df.expanding(1).mean()

for col in ["tmax", "tmin", "prcp"]:
    weather[f"month_avg_{col}"] = weather[col].groupby(weather.index.month, group_keys=False).apply(expand_mean) # this line of code calculates the monthly average of a specific column (col) in the weather DataFrame and stores these averages in a new column named f"month_avg_{col}
    weather[f"day_avg_{col}"] = weather[col].groupby(weather.index.day_of_year, group_keys=False).apply(expand_mean)

# %%
weather = weather.iloc[14:,:]  #it will cut out the first 14 rows as it has missing values
weather = weather.fillna(0) #it finds any missing values and fill it with 0

# %%
predictors = weather.columns[~weather.columns.isin(["target", "name", "station"])]

# %%
predictions = backtest(weather, rr, predictors)
mean_absolute_error(predictions["actual"], predictions["prediction"])
# Out:
# 4.7928723896754155

# %%
mean_squared_error(predictions["actual"], predictions["prediction"])
# Out:
# 37.61640813565289

# %%
predictions.sort_values("diff", ascending=False)
# Out:
#             actual  prediction       diff
# DATE
# 1990-03-12    85.0   54.369353  30.630647
# 2007-03-26    78.0   49.981156  28.018844
# 1998-03-26    80.0   52.009052  27.990948
# 2003-04-15    86.0   59.418323  26.581677
# 1985-04-18    84.0   58.463358  25.536642
# ...            ...         ...        ...
# 2001-12-02    53.0   53.002346   0.002346
# 1986-08-05    82.0   82.001182   0.001182
# 1985-08-03    80.0   79.999022   0.000978
# 1983-04-23    59.0   59.000813   0.000813
# 2014-01-25    36.0   35.999195   0.000805
#
# [15623 rows x 3 columns]

# %% [markdown]
# # Data Exploration

# %%
weather.loc["1990-03-07": "1990-03-17"]
# Out:
#                 station                              name  prcp  snow  snwd  \
# DATE
# 1990-03-07  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   2.0
# 1990-03-08  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   1.0
# 1990-03-09  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.01   0.0   0.0
# 1990-03-10  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.01   0.0   0.0
# 1990-03-11  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.05   0.0   0.0
# 1990-03-12  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1990-03-13  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1990-03-14  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1990-03-15  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1990-03-16  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1990-03-17  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.26   0.0   0.0
#
# ...

# %%
(predictions["diff"].round().value_counts().sort_index() / predictions.shape[0]).plot()
# Out:
# <Axes: xlabel='diff'>

# %% [markdown]
# # Final OUTPUT

# %%
predictions
# Out:
#             actual  prediction       diff
# DATE
# 1980-01-13    54.0   32.430619  21.569381
# 1980-01-14    51.0   44.600179   6.399821
# 1980-01-15    45.0   46.846655   1.846655
# 1980-01-16    40.0   42.211921   2.211921
# 1980-01-17    41.0   40.865606   0.134394
# ...            ...         ...        ...
# 2022-10-17    58.0   67.303985   9.303985
# 2022-10-18    56.0   62.355455   6.355455
# 2022-10-19    61.0   59.688925   1.311075
# 2022-10-20    64.0   62.128871   1.871129
# 2022-10-21    64.0   63.122255   0.877745
#
# [15623 rows x 3 columns]
